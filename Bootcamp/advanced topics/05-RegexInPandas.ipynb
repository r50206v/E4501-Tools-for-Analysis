# %% [markdown]
# # Regex In Pandas

# %%
import pandas as pd

# %%
# https://data.medicare.gov/Nursing-Home-Compare/Skilled-Nursing-Facility-Quality-Reporting-Program/fykj-qjee
df = pd.read_csv('Skilled_Nursing_Facility_Quality_Reporting_Program_-_Provider_Data.csv', index_col=[0, 10])
df.head()
# Out:
#                                                                           Facility Name  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         ST JOSEPH'S HEALTHCARE CENTER
#                                S_006_01_MSPB_SCORE        ST JOSEPH'S HEALTHCARE CENTER
# 235379                         S_004_01_PPR_PD_COMP_PERF        MEDILODGE OF TAWAS CITY
# 235414                         S_005_01_DTC_RS_RATE            THE VILLA AT WEST BRANCH
# 235431                         S_004_01_PPR_PD_COMP_PERF          SANCTUARY AT THE PARK
#
#                                                                  Address Line 1  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR            9400 CONANT STREET
#                                S_006_01_MSPB_SCORE           9400 CONANT STREET
# 235379                         S_004_01_PPR_PD_COMP_PERF  400 NORTH STREET WEST
# 235414                         S_005_01_DTC_RS_RATE             445 S VALLEY ST
# 235431                         S_004_01_PPR_PD_COMP_PERF    570 S HARVEY STREET
#
#                                                           Address Line 2  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR                    NaN
#                                S_006_01_MSPB_SCORE                   NaN
# 235379                         S_004_01_PPR_PD_COMP_PERF             NaN
# 235414                         S_005_01_DTC_RS_RATE                  NaN
# 235431                         S_004_01_PPR_PD_COMP_PERF             NaN
#
#                                                                  City State  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR           HAMTRAMCK    MI
#                                S_006_01_MSPB_SCORE          HAMTRAMCK    MI
# 235379                         S_004_01_PPR_PD_COMP_PERF   TAWAS CITY    MI
# 235414                         S_005_01_DTC_RS_RATE       WEST BRANCH    MI
# 235431                         S_004_01_PPR_PD_COMP_PERF     MUSKEGON    MI
#
#                                                           Zip Code  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR            48212
#                                S_006_01_MSPB_SCORE           48212
# 235379                         S_004_01_PPR_PD_COMP_PERF     48763
# 235414                         S_005_01_DTC_RS_RATE          48661
# 235431                         S_004_01_PPR_PD_COMP_PERF     49442
#
#                                                          County Name  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR              Wayne
#                                S_006_01_MSPB_SCORE             Wayne
# 235379                         S_004_01_PPR_PD_COMP_PERF       Iosco
# 235414                         S_005_01_DTC_RS_RATE           Ogemaw
# 235431                         S_004_01_PPR_PD_COMP_PERF    Muskegon
#
#                                                            Phone Number  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         (313)874-4500
#                                S_006_01_MSPB_SCORE        (313)874-4500
# 235379                         S_004_01_PPR_PD_COMP_PERF  (989)362-8645
# 235414                         S_005_01_DTC_RS_RATE       (989)345-3600
# 235431                         S_004_01_PPR_PD_COMP_PERF  (231)672-2202
#
#                                                           CMS Region  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR                  5
#                                S_006_01_MSPB_SCORE                 5
# 235379                         S_004_01_PPR_PD_COMP_PERF           5
# 235414                         S_005_01_DTC_RS_RATE                5
# 235431                         S_004_01_PPR_PD_COMP_PERF           5
#
#                                                                   Score  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR                     0
#                                S_006_01_MSPB_SCORE                 1.09
# 235379                         S_004_01_PPR_PD_COMP_PERF  Not Available
# 235414                         S_005_01_DTC_RS_RATE               54.69
# 235431                         S_004_01_PPR_PD_COMP_PERF  Not Available
#
#                                                          Footnote  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR             NaN
#                                S_006_01_MSPB_SCORE            NaN
# 235379                         S_004_01_PPR_PD_COMP_PERF       16
# 235414                         S_005_01_DTC_RS_RATE           NaN
# 235431                         S_004_01_PPR_PD_COMP_PERF       16
#
#                                                           no_QRP flag  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR                 NaN
#                                S_006_01_MSPB_SCORE                NaN
# 235379                         S_004_01_PPR_PD_COMP_PERF          NaN
# 235414                         S_005_01_DTC_RS_RATE               NaN
# 235431                         S_004_01_PPR_PD_COMP_PERF          NaN
#
#                                                           Start Date  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         07/01/2017
#                                S_006_01_MSPB_SCORE        10/01/2016
# 235379                         S_004_01_PPR_PD_COMP_PERF  10/01/2015
# 235414                         S_005_01_DTC_RS_RATE       10/01/2016
# 235431                         S_004_01_PPR_PD_COMP_PERF  10/01/2015
#
#                                                             End Date  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         06/30/2018
#                                S_006_01_MSPB_SCORE        09/30/2017
# 235379                         S_004_01_PPR_PD_COMP_PERF  09/30/2017
# 235414                         S_005_01_DTC_RS_RATE       09/30/2017
# 235431                         S_004_01_PPR_PD_COMP_PERF  09/30/2017
#
#                                                                                                  Location 1
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         9400 CONANT STREET HAMTRAMCK, MI 48212 (42.397...
#                                S_006_01_MSPB_SCORE        9400 CONANT STREET HAMTRAMCK, MI 48212 (42.397...
# 235379                         S_004_01_PPR_PD_COMP_PERF  400 NORTH STREET WEST TAWAS CITY, MI 48763 (44...
# 235414                         S_005_01_DTC_RS_RATE       445 S VALLEY ST WEST BRANCH, MI 48661 (44.2726...
# 235431                         S_004_01_PPR_PD_COMP_PERF  570 S HARVEY STREET MUSKEGON, MI 49442 (43.241...

# %%
df.loc[:, 'Location 1'].head()
# Out:
# CMS Certification Number (CCN)  Measure Code
# 235383                          S_013_01_NUMERATOR           9400 CONANT STREET HAMTRAMCK, MI 48212 (42.397...
#                                 S_006_01_MSPB_SCORE          9400 CONANT STREET HAMTRAMCK, MI 48212 (42.397...
# 235379                          S_004_01_PPR_PD_COMP_PERF    400 NORTH STREET WEST TAWAS CITY, MI 48763 (44...
# 235414                          S_005_01_DTC_RS_RATE         445 S VALLEY ST WEST BRANCH, MI 48661 (44.2726...
# 235431                          S_004_01_PPR_PD_COMP_PERF    570 S HARVEY STREET MUSKEGON, MI 49442 (43.241...
# Name: Location 1, dtype: object

# %%
df.loc[:, 'Location 1'].str[-25:].head()  # .str method gives access to string in column
# Out:
# CMS Certification Number (CCN)  Measure Code
# 235383                          S_013_01_NUMERATOR           2 (42.397239, -83.049168)
#                                 S_006_01_MSPB_SCORE          2 (42.397239, -83.049168)
# 235379                          S_004_01_PPR_PD_COMP_PERF    3 (44.272532, -83.520777)
# 235414                          S_005_01_DTC_RS_RATE         1 (44.272658, -84.230672)
# 235431                          S_004_01_PPR_PD_COMP_PERF    2 (43.241767, -86.204022)
# Name: Location 1, dtype: object

# %%
# df.loc[:, 'Location 1'].str. / cat / replace / upper / lower / split / ...

# %%
pattern = r'\((?P<lat>[^,]+), (?P<long>.+)\)'
lat_long_df = df.loc[:, 'Location 1'].str.extract(pattern)
lat_long_df.head()
# Out:
#                                                                 lat  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         42.397239
#                                S_006_01_MSPB_SCORE        42.397239
# 235379                         S_004_01_PPR_PD_COMP_PERF  44.272532
# 235414                         S_005_01_DTC_RS_RATE       44.272658
# 235431                         S_004_01_PPR_PD_COMP_PERF  43.241767
#
#                                                                 long
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         -83.049168
#                                S_006_01_MSPB_SCORE        -83.049168
# 235379                         S_004_01_PPR_PD_COMP_PERF  -83.520777
# 235414                         S_005_01_DTC_RS_RATE       -84.230672
# 235431                         S_004_01_PPR_PD_COMP_PERF  -86.204022

# %%
lat_long_df.info()  # columns are strings...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 403988 entries, (235383, S_013_01_NUMERATOR) to (455484, S_004_01_PPR_PD_COMP_PERF)
# Data columns (total 2 columns):
# lat     374426 non-null object
# long    374426 non-null object
# dtypes: object(2)
# memory usage: 7.4+ MB

# %%
lat_long_df.astype('float').info()  # lets cast to floats so they can be used as lat, long in other operations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 403988 entries, (235383, S_013_01_NUMERATOR) to (455484, S_004_01_PPR_PD_COMP_PERF)
# Data columns (total 2 columns):
# lat     374426 non-null float64
# long    374426 non-null float64
# dtypes: float64(2)
# memory usage: 7.4+ MB

# %%
df2 = df.join(lat_long_df.astype('float'))  # We'll get to joining DataFrames soon
df2.head()
# Out:
#                                                                           Facility Name  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         ST JOSEPH'S HEALTHCARE CENTER
#                                S_006_01_MSPB_SCORE        ST JOSEPH'S HEALTHCARE CENTER
# 235379                         S_004_01_PPR_PD_COMP_PERF        MEDILODGE OF TAWAS CITY
# 235414                         S_005_01_DTC_RS_RATE            THE VILLA AT WEST BRANCH
# 235431                         S_004_01_PPR_PD_COMP_PERF          SANCTUARY AT THE PARK
#
#                                                                  Address Line 1  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR            9400 CONANT STREET
#                                S_006_01_MSPB_SCORE           9400 CONANT STREET
# 235379                         S_004_01_PPR_PD_COMP_PERF  400 NORTH STREET WEST
# 235414                         S_005_01_DTC_RS_RATE             445 S VALLEY ST
# 235431                         S_004_01_PPR_PD_COMP_PERF    570 S HARVEY STREET
#
#                                                           Address Line 2  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR                    NaN
#                                S_006_01_MSPB_SCORE                   NaN
# 235379                         S_004_01_PPR_PD_COMP_PERF             NaN
# 235414                         S_005_01_DTC_RS_RATE                  NaN
# 235431                         S_004_01_PPR_PD_COMP_PERF             NaN
#
#                                                                  City State  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR           HAMTRAMCK    MI
#                                S_006_01_MSPB_SCORE          HAMTRAMCK    MI
# 235379                         S_004_01_PPR_PD_COMP_PERF   TAWAS CITY    MI
# 235414                         S_005_01_DTC_RS_RATE       WEST BRANCH    MI
# 235431                         S_004_01_PPR_PD_COMP_PERF     MUSKEGON    MI
#
#                                                           Zip Code  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR            48212
#                                S_006_01_MSPB_SCORE           48212
# 235379                         S_004_01_PPR_PD_COMP_PERF     48763
# 235414                         S_005_01_DTC_RS_RATE          48661
# 235431                         S_004_01_PPR_PD_COMP_PERF     49442
#
#                                                          County Name  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR              Wayne
#                                S_006_01_MSPB_SCORE             Wayne
# 235379                         S_004_01_PPR_PD_COMP_PERF       Iosco
# 235414                         S_005_01_DTC_RS_RATE           Ogemaw
# 235431                         S_004_01_PPR_PD_COMP_PERF    Muskegon
#
#                                                            Phone Number  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         (313)874-4500
#                                S_006_01_MSPB_SCORE        (313)874-4500
# 235379                         S_004_01_PPR_PD_COMP_PERF  (989)362-8645
# 235414                         S_005_01_DTC_RS_RATE       (989)345-3600
# 235431                         S_004_01_PPR_PD_COMP_PERF  (231)672-2202
#
#                                                           CMS Region  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR                  5
#                                S_006_01_MSPB_SCORE                 5
# 235379                         S_004_01_PPR_PD_COMP_PERF           5
# 235414                         S_005_01_DTC_RS_RATE                5
# 235431                         S_004_01_PPR_PD_COMP_PERF           5
#
#                                                                   Score  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR                     0
#                                S_006_01_MSPB_SCORE                 1.09
# 235379                         S_004_01_PPR_PD_COMP_PERF  Not Available
# 235414                         S_005_01_DTC_RS_RATE               54.69
# 235431                         S_004_01_PPR_PD_COMP_PERF  Not Available
#
#                                                          Footnote  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR             NaN
#                                S_006_01_MSPB_SCORE            NaN
# 235379                         S_004_01_PPR_PD_COMP_PERF       16
# 235414                         S_005_01_DTC_RS_RATE           NaN
# 235431                         S_004_01_PPR_PD_COMP_PERF       16
#
#                                                           no_QRP flag  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR                 NaN
#                                S_006_01_MSPB_SCORE                NaN
# 235379                         S_004_01_PPR_PD_COMP_PERF          NaN
# 235414                         S_005_01_DTC_RS_RATE               NaN
# 235431                         S_004_01_PPR_PD_COMP_PERF          NaN
#
#                                                           Start Date  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         07/01/2017
#                                S_006_01_MSPB_SCORE        10/01/2016
# 235379                         S_004_01_PPR_PD_COMP_PERF  10/01/2015
# 235414                         S_005_01_DTC_RS_RATE       10/01/2016
# 235431                         S_004_01_PPR_PD_COMP_PERF  10/01/2015
#
#                                                             End Date  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         06/30/2018
#                                S_006_01_MSPB_SCORE        09/30/2017
# 235379                         S_004_01_PPR_PD_COMP_PERF  09/30/2017
# 235414                         S_005_01_DTC_RS_RATE       09/30/2017
# 235431                         S_004_01_PPR_PD_COMP_PERF  09/30/2017
#
#                                                                                                  Location 1  \
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         9400 CONANT STREET HAMTRAMCK, MI 48212 (42.397...
#                                S_006_01_MSPB_SCORE        9400 CONANT STREET HAMTRAMCK, MI 48212 (42.397...
# 235379                         S_004_01_PPR_PD_COMP_PERF  400 NORTH STREET WEST TAWAS CITY, MI 48763 (44...
# 235414                         S_005_01_DTC_RS_RATE       445 S VALLEY ST WEST BRANCH, MI 48661 (44.2726...
# 235431                         S_004_01_PPR_PD_COMP_PERF  570 S HARVEY STREET MUSKEGON, MI 49442 (43.241...
#
#                                                                 lat       long
# CMS Certification Number (CCN) Measure Code
# 235383                         S_013_01_NUMERATOR         42.397239 -83.049168
#                                S_006_01_MSPB_SCORE        42.397239 -83.049168
# 235379                         S_004_01_PPR_PD_COMP_PERF  44.272532 -83.520777
# 235414                         S_005_01_DTC_RS_RATE       44.272658 -84.230672
# 235431                         S_004_01_PPR_PD_COMP_PERF  43.241767 -86.204022

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap  
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-09247a0eee89> in <module>
#       2
#       3 import matplotlib.pyplot as plt
# ----> 4 from mpl_toolkits.basemap import Basemap
#       5 import numpy as np
#
# /opt/conda/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in <module>
#     150
#     151 # create dictionary that maps epsg codes to Basemap kwargs.
# --> 152 pyproj_datadir = os.environ['PROJ_LIB']
#     153 epsgf = open(os.path.join(pyproj_datadir,'epsg'))
#     154 epsg_dict={}
#
# /opt/conda/lib/python3.7/os.py in __getitem__(self, key)
#     676         except KeyError:
#     677             # raise KeyError with the original key value
# --> 678             raise KeyError(key) from None
#     679         return self.decodevalue(value)
#     680
#
# KeyError: 'PROJ_LIB'

# %%
# KeyError: 'PROJ_LIB'? 
# https://github.com/matplotlib/basemap/issues/419#issuecomment-418155703

# %%
plt.figure(figsize=(15, 15))

m = Basemap(
    projection='mill', 
    lat_0=36, 
    lon_0=-95, 
    llcrnrlon=-125,
    llcrnrlat=25,
    urcrnrlon=-67,
    urcrnrlat=50,
    resolution='l',
)
m.drawcoastlines(linewidth=0.25)
m.drawcountries(linewidth=0.25)

lat = np.array(df2.loc[:, 'lat'])
long = np.array(df2.loc[:, 'long'])

x, y = m(long, lat)

plt.scatter(
    x, 
    y, 
    marker='o', 
    color='r',
    s=1,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8e329c002adf> in <module>()
#       1 plt.figure(figsize=(15, 15))
#       2
# ----> 3 m = Basemap(
#       4     projection='mill',
#       5     lat_0=36,
#
# NameError: name 'Basemap' is not defined
