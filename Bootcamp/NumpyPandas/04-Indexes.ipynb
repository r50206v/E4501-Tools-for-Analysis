# %% [markdown]
# # Hierarchy in Indexes

# %%
import pandas as pd

# %%
df = pd.read_csv(
    'WSH_HYGIENE_BASIC.csv', 
    header=[0, 2],
    index_col=0,
)  
df.head()
# Out:
#              2015              2014              2013              2012  ...  \
# Country     Rural Urban Total Rural Urban Total Rural Urban Total Rural  ...
# Afghanistan  29.0  64.0  38.0  29.0  64.0  38.0  29.0  64.0  38.0  29.0  ...
# Algeria      73.0  88.0  84.0  73.0  88.0  83.0  73.0  88.0  83.0  73.0  ...
# Angola       15.0  37.0  25.0  15.0  37.0  24.0  15.0  37.0  24.0  15.0  ...
# Armenia      77.0  93.0  87.0  77.0  93.0  87.0  77.0  93.0  87.0  77.0  ...
# Bangladesh   31.0  58.0  40.0  31.0  58.0  40.0  31.0  58.0  40.0  31.0  ...
#
#              2003  2002              2001              2000
# Country     Total Rural Urban Total Rural Urban Total Rural Urban Total
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Armenia      85.0  68.0  94.0  84.0  67.0  94.0  84.0  66.0  94.0  84.0
# Bangladesh    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 48 columns]

# %%
# How coud we have made something like the chart above with the basics of Pandas
df.loc['Afghanistan':'Bangladesh', '2015']
# Out:
# Country      Rural  Urban  Total
# Afghanistan   29.0   64.0   38.0
# Algeria       73.0   88.0   84.0
# Angola        15.0   37.0   25.0
# Armenia       77.0   93.0   87.0
# Bangladesh    31.0   58.0   40.0

# %%
rural = {
    'Afghanistan': 29.0,
    'Algeria': 73.0,
    'Angola': 15.0,
    'Armenia': 77.0,
    'Bangladesh': 31.0,
}

urban = {
    'Afghanistan': 64.0,
    'Algeria': 88.0,
    'Angola': 37.0,
    'Armenia': 93.0,
    'Bangladesh': 58.0,
}

total = {
    'Afghanistan': 38.0,
    'Algeria': 84.0,
    'Angola': 25.0,
    'Armenia': 87.0,
    'Bangladesh': 40.0,
}

data = {
    'Rural': pd.Series(rural),
    'Urban': pd.Series(urban),
    'Total': pd.Series(total),
}

df = pd.DataFrame(data)  # Not quite it..
df
# Out:
#              Rural  Urban  Total
# Afghanistan   29.0   64.0   38.0
# Algeria       73.0   88.0   84.0
# Angola        15.0   37.0   25.0
# Armenia       77.0   93.0   87.0
# Bangladesh    31.0   58.0   40.0

# %%
columns = pd.MultiIndex.from_product([['2015'], ['Rural', 'Total', 'Urban']])
columns
# Out:
# MultiIndex([('2015', 'Rural'),
#             ('2015', 'Total'),
#             ('2015', 'Urban')],
#            )

# %%
index = pd.Index(['Afghanistan', 'Algeria', 'Angola', 'Armenia', 'Bangladesh'])
index
# Out:
# Index(['Afghanistan', 'Algeria', 'Angola', 'Armenia', 'Bangladesh'], dtype='object')

# %%
values = df.values
values
# Out:
# array([[29., 64., 38.],
#        [73., 88., 84.],
#        [15., 37., 25.],
#        [77., 93., 87.],
#        [31., 58., 40.]])

# %%
df = pd.DataFrame(values, index=index, columns=columns)
df
# Out:
#              2015
#             Rural Total Urban
# Afghanistan  29.0  64.0  38.0
# Algeria      73.0  88.0  84.0
# Angola       15.0  37.0  25.0
# Armenia      77.0  93.0  87.0
# Bangladesh   31.0  58.0  40.0

# %%
df.stack()  # Move a level of columns to be part of the row index
# Out:
#                    2015
# Afghanistan Rural  29.0
#             Total  64.0
#             Urban  38.0
# Algeria     Rural  73.0
#             Total  88.0
#             Urban  84.0
# Angola      Rural  15.0
#             Total  37.0
#             Urban  25.0
# Armenia     Rural  77.0
#             Total  93.0
#             Urban  87.0
# Bangladesh  Rural  31.0
#             Total  58.0
#             Urban  40.0

# %%
df.stack().stack()  # Move another level of column to be part of the row index
# Out:
# Afghanistan  Rural  2015    29.0
#              Total  2015    64.0
#              Urban  2015    38.0
# Algeria      Rural  2015    73.0
#              Total  2015    88.0
#              Urban  2015    84.0
# Angola       Rural  2015    15.0
#              Total  2015    37.0
#              Urban  2015    25.0
# Armenia      Rural  2015    77.0
#              Total  2015    93.0
#              Urban  2015    87.0
# Bangladesh   Rural  2015    31.0
#              Total  2015    58.0
#              Urban  2015    40.0
# dtype: float64

# %%
df.stack().stack().unstack()  # Move a level of index to be part of the columns
# Out:
#                    2015
# Afghanistan Rural  29.0
#             Total  64.0
#             Urban  38.0
# Algeria     Rural  73.0
#             Total  88.0
#             Urban  84.0
# Angola      Rural  15.0
#             Total  37.0
#             Urban  25.0
# Armenia     Rural  77.0
#             Total  93.0
#             Urban  87.0
# Bangladesh  Rural  31.0
#             Total  58.0
#             Urban  40.0

# %%
df.stack().stack().unstack().unstack()  # Move a level of index to be part of the columns
# Out:
#              2015
#             Rural Total Urban
# Afghanistan  29.0  64.0  38.0
# Algeria      73.0  88.0  84.0
# Angola       15.0  37.0  25.0
# Armenia      77.0  93.0  87.0
# Bangladesh   31.0  58.0  40.0

# %% [markdown]
# ### Indexing

# %%
df = pd.read_csv(
    'WSH_HYGIENE_BASIC.csv', 
    header=[0, 2],
    index_col=0,
)  
df.head()
# Out:
#              2015              2014              2013              2012  ...  \
# Country     Rural Urban Total Rural Urban Total Rural Urban Total Rural  ...
# Afghanistan  29.0  64.0  38.0  29.0  64.0  38.0  29.0  64.0  38.0  29.0  ...
# Algeria      73.0  88.0  84.0  73.0  88.0  83.0  73.0  88.0  83.0  73.0  ...
# Angola       15.0  37.0  25.0  15.0  37.0  24.0  15.0  37.0  24.0  15.0  ...
# Armenia      77.0  93.0  87.0  77.0  93.0  87.0  77.0  93.0  87.0  77.0  ...
# Bangladesh   31.0  58.0  40.0  31.0  58.0  40.0  31.0  58.0  40.0  31.0  ...
#
#              2003  2002              2001              2000
# Country     Total Rural Urban Total Rural Urban Total Rural Urban Total
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Armenia      85.0  68.0  94.0  84.0  67.0  94.0  84.0  66.0  94.0  84.0
# Bangladesh    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 48 columns]

# %%
df.loc[:, '2015'].head()  # First index operation operates on the outer layer of the hierarchical index.
# Out:
# Country      Rural  Urban  Total
# Afghanistan   29.0   64.0   38.0
# Algeria       73.0   88.0   84.0
# Angola        15.0   37.0   25.0
# Armenia       77.0   93.0   87.0
# Bangladesh    31.0   58.0   40.0

# %%
df.loc[:, ('2015', 'Rural')].head()  # Second moves us down through the second level of the index, use tuple
# Out:
# Afghanistan    29.0
# Algeria        73.0
# Angola         15.0
# Armenia        77.0
# Bangladesh     31.0
# Name: (2015, Rural), dtype: float64

# %%
df.loc['Algeria', ('2015', 'Rural')]
# Out:
# 73.0

# %% [markdown]
# ### Slicing

# %%
df.loc['Chad':'Costa Rica']  # Slicing still works
# Out:
#             2015              2014              2013              2012  ...  \
# Country    Rural Urban Total Rural Urban Total Rural Urban Total Rural  ...
# Chad         2.0  18.0   6.0   2.0  18.0   6.0   2.0  18.0   6.0   2.0  ...
# Comoros     15.0  18.0  16.0  15.0  18.0  16.0  15.0  18.0  16.0  15.0  ...
# Costa Rica  83.0  84.0  84.0  83.0  84.0  84.0  83.0  84.0  84.0  83.0  ...
#
#             2003  2002              2001              2000
# Country    Total Rural Urban Total Rural Urban Total Rural Urban Total
# Chad         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Comoros      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Costa Rica   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [3 rows x 48 columns]

# %%
df.loc['Chad':'Costa Rica', '2010':'2015']  # UnsortedIndexError, hmmm
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# <ipython-input-18-149a38034a2d> in <module>
# ----> 1 df.loc['Chad':'Costa Rica', '2010':'2015']  # UnsortedIndexError, hmmm
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     803     def _getitem_tuple(self, tup):
#     804         try:
# --> 805             return self._getitem_lowerdim(tup)
#     806         except IndexingError:
#     807             pass
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     908         # we may have a nested tuples indexer here
#     909         if self._is_nested_tuple_indexer(tup):
# --> 910             return self._getitem_nested_tuple(tup)
#     911
#     912         # we maybe be using a tuple to represent multiple dimensions here
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_nested_tuple(self, tup)
#     991
#     992             current_ndim = obj.ndim
# --> 993             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#     994             axis += 1
#     995
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1795         if isinstance(key, slice):
#    1796             self._validate_key(key, axis)
# -> 1797             return self._get_slice_axis(key, axis=axis)
#    1798         elif com.is_bool_indexer(key):
#    1799             return self._getbool_axis(key, axis=axis)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1452         labels = obj._get_axis(axis)
#    1453         indexer = labels.slice_indexer(
# -> 1454             slice_obj.start, slice_obj.stop, slice_obj.step, kind=self.name
#    1455         )
#    1456
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    5032         slice(1, 3)
#    5033         """
# -> 5034         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    5035
#    5036         # return a slice
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/multi.py in slice_locs(self, start, end, step, kind)
#    2579         # This function adds nothing to its parent implementation (the magic
#    2580         # happens in get_slice_bound method), but it adds meaningful doc.
# -> 2581         return super().slice_locs(start, end, step, kind=kind)
#    2582
#    2583     def _partial_tup_index(self, tup, side="left"):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    5246         start_slice = None
#    5247         if start is not None:
# -> 5248             start_slice = self.get_slice_bound(start, "left", kind)
#    5249         if start_slice is None:
#    5250             start_slice = 0
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/multi.py in get_slice_bound(self, label, side, kind)
#    2523         if not isinstance(label, tuple):
#    2524             label = (label,)
# -> 2525         return self._partial_tup_index(label, side=side)
#    2526
#    2527     def slice_locs(self, start=None, end=None, step=None, kind=None):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/multi.py in _partial_tup_index(self, tup, side)
#    2585             raise UnsortedIndexError(
#    2586                 "Key length (%d) was greater than MultiIndex"
# -> 2587                 " lexsort depth (%d)" % (len(tup), self.lexsort_depth)
#    2588             )
#    2589
#
# UnsortedIndexError: 'Key length (1) was greater than MultiIndex lexsort depth (0)'

# %%
df.columns.lexsort_depth  # Looks like the column indexes are not sorted by Pandas terms
# Out:
# 0

# %%
df = df.sort_index(axis=1)  # Sort the column index with axis = 1
df.head()  # Notice years ascend now
# Out:
#              2000              2001              2002              2003  ...  \
# Country     Rural Total Urban Rural Total Urban Rural Total Urban Rural  ...
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Armenia      66.0  84.0  94.0  67.0  84.0  94.0  68.0  84.0  94.0  69.0  ...
# Bangladesh    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#              2012  2013              2014              2015
# Country     Urban Rural Total Urban Rural Total Urban Rural Total Urban
# Afghanistan  64.0  29.0  38.0  64.0  29.0  38.0  64.0  29.0  38.0  64.0
# Algeria      88.0  73.0  83.0  88.0  73.0  83.0  88.0  73.0  84.0  88.0
# Angola       37.0  15.0  24.0  37.0  15.0  24.0  37.0  15.0  25.0  37.0
# Armenia      93.0  77.0  87.0  93.0  77.0  87.0  93.0  77.0  87.0  93.0
# Bangladesh   58.0  31.0  40.0  58.0  31.0  40.0  58.0  31.0  40.0  58.0
#
# [5 rows x 48 columns]

# %%
df.columns.lexsort_depth
# Out:
# 2

# %%
df.loc['Chad':'Costa Rica', '2010':'2015']
# Out:
#             2010              2011              2012              2013        \
# Country    Rural Total Urban Rural Total Urban Rural Total Urban Rural Total
# Chad         NaN   NaN   NaN   2.0   6.0  18.0   2.0   6.0  18.0   2.0   6.0
# Comoros     15.0  16.0  18.0  15.0  16.0  18.0  15.0  16.0  18.0  15.0  16.0
# Costa Rica  83.0  84.0  84.0  83.0  84.0  84.0  83.0  84.0  84.0  83.0  84.0
#
#                   2014              2015
# Country    Urban Rural Total Urban Rural Total Urban
# Chad        18.0   2.0   6.0  18.0   2.0   6.0  18.0
# Comoros     18.0  15.0  16.0  18.0  15.0  16.0  18.0
# Costa Rica  84.0  83.0  84.0  84.0  83.0  84.0  84.0

# %%
df.loc['Chad':'Costa Rica', ('2010':'2015', 'Rural')]  # SyntaxErrors
# Out:
#   File "<ipython-input-23-2650bc3e9274>", line 1
#     df.loc['Chad':'Costa Rica', ('2010':'2015', 'Rural')]  # SyntaxErrors
#                                        ^
# SyntaxError: invalid syntax

# %%
years = pd.IndexSlice['2010':'2015', 'Rural']
df.loc['Chad':'Costa Rica', years]
# Out:
#             2010  2011  2012  2013  2014  2015
# Country    Rural Rural Rural Rural Rural Rural
# Chad         NaN   2.0   2.0   2.0   2.0   2.0
# Comoros     15.0  15.0  15.0  15.0  15.0  15.0
# Costa Rica  83.0  83.0  83.0  83.0  83.0  83.0

# %%
# Setting, Reseting indexes
df = pd.read_csv(
    'WSH_HYGIENE_BASIC.csv', 
    header=[0, 2],
    index_col=0,
)  
df.head()
# Out:
#              2015              2014              2013              2012  ...  \
# Country     Rural Urban Total Rural Urban Total Rural Urban Total Rural  ...
# Afghanistan  29.0  64.0  38.0  29.0  64.0  38.0  29.0  64.0  38.0  29.0  ...
# Algeria      73.0  88.0  84.0  73.0  88.0  83.0  73.0  88.0  83.0  73.0  ...
# Angola       15.0  37.0  25.0  15.0  37.0  24.0  15.0  37.0  24.0  15.0  ...
# Armenia      77.0  93.0  87.0  77.0  93.0  87.0  77.0  93.0  87.0  77.0  ...
# Bangladesh   31.0  58.0  40.0  31.0  58.0  40.0  31.0  58.0  40.0  31.0  ...
#
#              2003  2002              2001              2000
# Country     Total Rural Urban Total Rural Urban Total Rural Urban Total
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Armenia      85.0  68.0  94.0  84.0  67.0  94.0  84.0  66.0  94.0  84.0
# Bangladesh    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 48 columns]

# %%
df.reset_index(col_fill='Ct').head()  # Turn the country index into a regular column.
# Out:
#                index  2015              2014              2013              \
# Country           Ct Rural Urban Total Rural Urban Total Rural Urban Total
# 0        Afghanistan  29.0  64.0  38.0  29.0  64.0  38.0  29.0  64.0  38.0
# 1            Algeria  73.0  88.0  84.0  73.0  88.0  83.0  73.0  88.0  83.0
# 2             Angola  15.0  37.0  25.0  15.0  37.0  24.0  15.0  37.0  24.0
# 3            Armenia  77.0  93.0  87.0  77.0  93.0  87.0  77.0  93.0  87.0
# 4         Bangladesh  31.0  58.0  40.0  31.0  58.0  40.0  31.0  58.0  40.0
#
#          ...  2003  2002              2001              2000
# Country  ... Total Rural Urban Total Rural Urban Total Rural Urban Total
# 0        ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1        ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2        ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3        ...  85.0  68.0  94.0  84.0  67.0  94.0  84.0  66.0  94.0  84.0
# 4        ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 49 columns]

# %%
# https://catalog.data.gov/dataset/demographic-statistics-by-zip-code-acfc9
df = pd.read_csv(
    'Demographic_Statistics_By_Zip_Code.csv', 
)  
df.head()
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10002                  35            19            0.54
# 2              10003                   1             1            1.00
# 3              10004                   0             0            0.00
# 4              10005                   2             2            1.00
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# 1          16          0.46                     0                       0
# 2           0          0.00                     0                       0
# 3           0          0.00                     0                       0
# 4           0          0.00                     0                       0
#
#    COUNT GENDER TOTAL  PERCENT GENDER TOTAL  ...  COUNT CITIZEN STATUS TOTAL  \
# 0                  44                   100  ...                          44
# 1                  35                   100  ...                          35
# 2                   1                   100  ...                           1
# 3                   0                     0  ...                           0
# 4                   2                   100  ...                           2
#
#    PERCENT CITIZEN STATUS TOTAL  COUNT RECEIVES PUBLIC ASSISTANCE  \
# 0                           100                                20
# 1                           100                                 2
# 2                           100                                 0
# 3                             0                                 0
# 4                           100                                 0
#
#    PERCENT RECEIVES PUBLIC ASSISTANCE  COUNT NRECEIVES PUBLIC ASSISTANCE  \
# 0                                0.45                                 24
# 1                                0.06                                 33
# 2                                0.00                                  1
# 3                                0.00                                  0
# 4                                0.00                                  2
#
#    PERCENT NRECEIVES PUBLIC ASSISTANCE  COUNT PUBLIC ASSISTANCE UNKNOWN  \
# 0                                 0.55                                0
# 1                                 0.94                                0
# 2                                 1.00                                0
# 3                                 0.00                                0
# 4                                 1.00                                0
#
#    PERCENT PUBLIC ASSISTANCE UNKNOWN  COUNT PUBLIC ASSISTANCE TOTAL  \
# 0                                  0                             44
# 1                                  0                             35
# 2                                  0                              1
# 3                                  0                              0
# 4                                  0                              2
#
#    PERCENT PUBLIC ASSISTANCE TOTAL
# 0                              100
# 1                              100
# 2                              100
# 3                                0
# 4                              100
#
# [5 rows x 46 columns]

# %%
df.set_index('JURISDICTION NAME').head()  # Take a current column and make it an index
# Out:
#                    COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# JURISDICTION NAME
# 10001                              44            22            0.50
# 10002                              35            19            0.54
# 10003                               1             1            1.00
# 10004                               0             0            0.00
# 10005                               2             2            1.00
#
#                    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  \
# JURISDICTION NAME
# 10001                      22          0.50                     0
# 10002                      16          0.46                     0
# 10003                       0          0.00                     0
# 10004                       0          0.00                     0
# 10005                       0          0.00                     0
#
#                    PERCENT GENDER UNKNOWN  COUNT GENDER TOTAL  \
# JURISDICTION NAME
# 10001                                   0                  44
# 10002                                   0                  35
# 10003                                   0                   1
# 10004                                   0                   0
# 10005                                   0                   2
#
#                    PERCENT GENDER TOTAL  COUNT PACIFIC ISLANDER  ...  \
# JURISDICTION NAME                                                ...
# 10001                               100                       0  ...
# 10002                               100                       0  ...
# 10003                               100                       0  ...
# 10004                                 0                       0  ...
# 10005                               100                       0  ...
#
#                    COUNT CITIZEN STATUS TOTAL  PERCENT CITIZEN STATUS TOTAL  \
# JURISDICTION NAME
# 10001                                      44                           100
# 10002                                      35                           100
# 10003                                       1                           100
# 10004                                       0                             0
# 10005                                       2                           100
#
#                    COUNT RECEIVES PUBLIC ASSISTANCE  \
# JURISDICTION NAME
# 10001                                            20
# 10002                                             2
# 10003                                             0
# 10004                                             0
# 10005                                             0
#
#                    PERCENT RECEIVES PUBLIC ASSISTANCE  \
# JURISDICTION NAME
# 10001                                            0.45
# 10002                                            0.06
# 10003                                            0.00
# 10004                                            0.00
# 10005                                            0.00
#
#                    COUNT NRECEIVES PUBLIC ASSISTANCE  \
# JURISDICTION NAME
# 10001                                             24
# 10002                                             33
# 10003                                              1
# 10004                                              0
# 10005                                              2
#
#                    PERCENT NRECEIVES PUBLIC ASSISTANCE  \
# JURISDICTION NAME
# 10001                                             0.55
# 10002                                             0.94
# 10003                                             1.00
# 10004                                             0.00
# 10005                                             1.00
#
#                    COUNT PUBLIC ASSISTANCE UNKNOWN  \
# JURISDICTION NAME
# 10001                                            0
# 10002                                            0
# 10003                                            0
# 10004                                            0
# 10005                                            0
#
#                    PERCENT PUBLIC ASSISTANCE UNKNOWN  \
# JURISDICTION NAME
# 10001                                              0
# 10002                                              0
# 10003                                              0
# 10004                                              0
# 10005                                              0
#
#                    COUNT PUBLIC ASSISTANCE TOTAL  \
# JURISDICTION NAME
# 10001                                         44
# 10002                                         35
# 10003                                          1
# 10004                                          0
# 10005                                          2
#
#                    PERCENT PUBLIC ASSISTANCE TOTAL
# JURISDICTION NAME
# 10001                                          100
# 10002                                          100
# 10003                                          100
# 10004                                            0
# 10005                                          100
#
# [5 rows x 45 columns]

# %%
# Aggregations
df = pd.read_csv(
    'WSH_HYGIENE_BASIC.csv', 
    header=[0, 2],
    index_col=0,
)  
df.head()
# Out:
#              2015              2014              2013              2012  ...  \
# Country     Rural Urban Total Rural Urban Total Rural Urban Total Rural  ...
# Afghanistan  29.0  64.0  38.0  29.0  64.0  38.0  29.0  64.0  38.0  29.0  ...
# Algeria      73.0  88.0  84.0  73.0  88.0  83.0  73.0  88.0  83.0  73.0  ...
# Angola       15.0  37.0  25.0  15.0  37.0  24.0  15.0  37.0  24.0  15.0  ...
# Armenia      77.0  93.0  87.0  77.0  93.0  87.0  77.0  93.0  87.0  77.0  ...
# Bangladesh   31.0  58.0  40.0  31.0  58.0  40.0  31.0  58.0  40.0  31.0  ...
#
#              2003  2002              2001              2000
# Country     Total Rural Urban Total Rural Urban Total Rural Urban Total
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Armenia      85.0  68.0  94.0  84.0  67.0  94.0  84.0  66.0  94.0  84.0
# Bangladesh    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 48 columns]

# %%
df.min(axis=1, level=0).head()  # Across all locations...
# Out:
#              2015  2014  2013  2012  2011  2010  2009  2008  2007  2006  2005  \
# Afghanistan  29.0  29.0  29.0  29.0  29.0  29.0  29.0  29.0  29.0  29.0  29.0
# Algeria      73.0  73.0  73.0  73.0  73.0  73.0  73.0   NaN   NaN   NaN   NaN
# Angola       15.0  15.0  15.0  15.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Armenia      77.0  77.0  77.0  77.0  76.0  75.0  74.0  73.0  73.0  72.0  71.0
# Bangladesh   31.0  31.0  31.0  31.0  31.0  31.0  31.0  31.0  31.0  31.0  31.0
#
#              2004  2003  2002  2001  2000
# Afghanistan   NaN   NaN   NaN   NaN   NaN
# Algeria       NaN   NaN   NaN   NaN   NaN
# Angola        NaN   NaN   NaN   NaN   NaN
# Armenia      70.0  69.0  68.0  67.0  66.0
# Bangladesh    NaN   NaN   NaN   NaN   NaN

# %%
df.mean(axis=1, level=1).head()  # For all years...
# Out:
# Country       Rural  Urban      Total
# Afghanistan  29.000  64.00  37.545455
# Algeria      73.000  88.00  83.142857
# Angola       15.000  37.00  24.250000
# Armenia      72.625  93.25  85.812500
# Bangladesh   31.000  58.00  39.181818

# %% [markdown]
# We have enough tools to do some basic analysis!
